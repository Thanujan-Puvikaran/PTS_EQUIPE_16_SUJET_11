# %%
import requests
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import  KFold
import warnings
import re
warnings.filterwarnings('ignore')

# %%
movies_db = pd.read_csv("movies_db_3.csv", delimiter=",",engine='python') #Provient de 3_Definition_Labels_X

# %%
scaler = StandardScaler()
scaler.fit(movies_db.drop(["target","title"],axis=1))
movies_model_data_scaled = scaler.transform(movies_db.drop(["target","title"],axis=1))
movies_model_data_scaled = pd.DataFrame(movies_model_data_scaled)
movies_model_data_scaled.columns = movies_db.drop(["target","title"],axis=1).columns
movies_model_data_scaled["target"] = movies_db["target"]
movies_model_data_scaled["title"] = movies_db["title"]
movies_model_data_scaled
# Out:
#             id    budget   revenue   runtime  pop_actors  vote_average  \
# 0    -0.624728 -0.610624 -0.457729 -0.198057    1.005341     -0.295833
# 1    -0.624723 -0.189900 -0.411709  0.225528   -0.030528      0.207533
# 2    -0.624697 -0.437385  4.045982  0.613814    0.613518      1.277184
# 3    -0.624692  1.616738  5.009271 -0.127460    1.019170      1.025501
# 4    -0.624687  0.651548  3.473570  1.355087    1.245193      1.465946
# ...        ...       ...       ...       ...         ...           ...
# 7088  1.383565 -0.412637 -0.423888  0.507917    0.037829      0.710898
# 7089  0.713926 -0.697244 -0.470912  0.578515   -1.405768     -0.232912
# 7090 -0.225489 -0.709611 -0.482591 -0.127460   -1.216405     -0.799198
# 7091  2.723784 -0.649610 -0.482592 -3.021955   -1.764970     -3.882311
# 7092  1.384526 -0.709617 -0.482592  1.355087   -1.442990     -0.421674
#
#       vote_count  pop_directors  pop_producer  target           title
# ...

# %%
scaler.mean_[[1,3,4,7,8]], scaler.var_[[1,3,4,7,8]]
# Out:
# (array([2.86732153e+07, 1.03610884e+02, 6.29233460e+01, 4.88691329e+00,
#         6.81374285e+00]),
#  array([1.63268781e+15, 8.02568171e+02, 1.27100987e+03, 3.48424234e+01,
#         1.05868464e+02]))

# %% [markdown]
# Export CSV

# %%
movies_model_data_scaled.to_csv("movies_db_5.csv",index=False)
